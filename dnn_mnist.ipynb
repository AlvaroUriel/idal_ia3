# %% [markdown]
# <a href="https://colab.research.google.com/github/AlvaroUriel/idal_ia3/blob/main/dnn_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entrenamiento de un Perceptrón Multi-Capa con datos de dígitos (MNIST)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
import matplotlib.pyplot as plt
tf.random.set_seed(42)

# %% [markdown]
# ## Carga de los datos
# #### Tamaño del conjunto de entrenamiento y de test

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

print(' -Entradas Entrenamiento:', X_train.shape)
print(' -Salidas Entrenamiento:', y_train.shape)
print(' -Entradas Test:', X_test.shape)
print(' -Salidas Test:', y_test.shape)
# Out:
#  -Entradas Entrenamiento: (60000, 28, 28)
#  -Salidas Entrenamiento: (60000,)
#  -Entradas Test: (10000, 28, 28)
#  -Salidas Test: (10000,)

# %% [markdown]
# #### Visualización de las entradas

# %%
n_img_show = 3

# Plot images
plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

print(f'Valores de salida correspondientes a las imágenes de entrada {y_train[0:n_img_show]}')
# Out:
# Valores de salida correspondientes a las imágenes de entrada [5 0 4]

# %% [markdown]
# ## Preparación de los datos
# #### Normalización

# %%
# Normalizamos a valores entre 0 y 1
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

# %% [markdown]
# #### Reajuste del tamaño de la entrada y la salida

# %%
x_shape = X_train.shape
X_train = X_train.reshape(x_shape[0], x_shape[1]*x_shape[2])
X_test = X_test.reshape(len(X_test), x_shape[1]*x_shape[2])
y_train = y_train[:, None]
y_test = y_test[:, None]

# Dibujar la nueva entrada
plt.figure(figsize=(20, 70))
plt.imshow(X_train[0:100], cmap='gray')
plt.xlabel('# Pixeles')
plt.ylabel('# Imágenes')
plt.colorbar(fraction=0.006);

# %% [markdown]
# ## Definición del modelo
# Crea un modelo con las siguientes capas:
# 1. Capa de entrada con tantas entradas como número de píxeles (784)
# 2. Capa oculta con 256 neuronas
# 3. Capa oculta con 128 neuronas
# 4. Capa oculta con 64 neuronas
# 5. Capa oculta con 32 neuronas
# 6. Capa de salidad con tantas neuronas como salidas (10)
#
# Todas las capas usan función de activación relu (menos la de salida). ¿Qué función de activación hay que poner a la salida?

# %%
from keras.models import Sequential  
from keras.layers import *  

# Algunos hiper-parámetros
lr = .001
batch_size = 512
n_epochs = 35
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

# Crear modelo
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=256, activation='relu', input_shape = (X_train.shape[1],)))
model.add(tf.keras.layers.Dense(128,       activation='relu'))
model.add(tf.keras.layers.Dense(64,        activation='relu'))
model.add(tf.keras.layers.Dense(32,        activation='relu'))
model.add(tf.keras.layers.Dense(10,        activation='softmax'))
#    .

# Visualizar arquitectura y dimensiones
model.summary()

# Compilamos el modelo: ¿Qué función de coste hay que utilizar?
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 256)               200960
#
#  dense_16 (Dense)            (None, 128)               32896
#
#  dense_17 (Dense)            (None, 64)                8256
#
#  dense_18 (Dense)            (None, 32)                2080
#
#  dense_19 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 244,522
# Trainable params: 244,522
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Entrenamiento del modelo

# %%
hist = model.fit(X_train, 
                 y_train, 
                 batch_size=batch_size, 
                 epochs=n_epochs, 
                 verbose=1, 
                 shuffle=True,
                 validation_data=(X_test, y_test))
# Out:
# Epoch 1/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.5074 - accuracy: 0.8424 - val_loss: 0.2119 - val_accuracy: 0.9364
# Epoch 2/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.1563 - accuracy: 0.9545 - val_loss: 0.1403 - val_accuracy: 0.9593
# Epoch 3/35
# 118/118 [==============================] - 1s 13ms/step - loss: 0.1090 - accuracy: 0.9679 - val_loss: 0.1005 - val_accuracy: 0.9705
# Epoch 4/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0804 - accuracy: 0.9758 - val_loss: 0.1012 - val_accuracy: 0.9683
# Epoch 5/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0639 - accuracy: 0.9808 - val_loss: 0.0870 - val_accuracy: 0.9734
# Epoch 6/35
# 118/118 [==============================] - 1s 13ms/step - loss: 0.0513 - accuracy: 0.9844 - val_loss: 0.0796 - val_accuracy: 0.9760
# Epoch 7/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0395 - accuracy: 0.9880 - val_loss: 0.0762 - val_accuracy: 0.9768
# Epoch 8/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0321 - accuracy: 0.9905 - val_loss: 0.0810 - val_accuracy: 0.9763
# Epoch 9/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0267 - accuracy: 0.9923 - val_loss: 0.0736 - val_accuracy: 0.9793
# Epoch 10/35
# 118/118 [==============================] - 1s 12ms/step - loss: 0.0227 - accuracy: 0.9930 - val_loss: 0.0789 - val_accuracy: 0.9773
# Epoch 11/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0222 - accuracy: 0.9931 - val_loss: 0.0804 - val_accuracy: 0.9780
# Epoch 12/35
# 118/118 [==============================] - 1s 13ms/step - loss: 0.0172 - accuracy: 0.9944 - val_loss: 0.0761 - val_accuracy: 0.9794
# Epoch 13/35
# 118/118 [==============================] - 1s 13ms/step - loss: 0.0126 - accuracy: 0.9962 - val_loss: 0.0783 - val_accuracy: 0.9790
# Epoch 14/35
# 118/118 [==============================] - 1s 13ms/step - loss: 0.0073 - accuracy: 0.9980 - val_loss: 0.0796 - val_accuracy: 0.9797
# Epoch 15/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0087 - accuracy: 0.9976 - val_loss: 0.0928 - val_accuracy: 0.9774
# Epoch 16/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.0829 - val_accuracy: 0.9796
# Epoch 17/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.0913 - val_accuracy: 0.9782
# Epoch 18/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 0.0900 - val_accuracy: 0.9777
# Epoch 19/35
# 118/118 [==============================] - 1s 13ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0984 - val_accuracy: 0.9769
# Epoch 20/35
# 118/118 [==============================] - 1s 12ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0840 - val_accuracy: 0.9803
# Epoch 21/35
# 118/118 [==============================] - 1s 13ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.0929 - val_accuracy: 0.9795
# Epoch 22/35
# 118/118 [==============================] - 1s 13ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0956 - val_accuracy: 0.9800
# Epoch 23/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.0841 - val_accuracy: 0.9818
# Epoch 24/35
# 118/118 [==============================] - 1s 13ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0936 - val_accuracy: 0.9793
# Epoch 25/35
# 118/118 [==============================] - 1s 13ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.1014 - val_accuracy: 0.9786
# Epoch 26/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.1037 - val_accuracy: 0.9796
# Epoch 27/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.0995 - val_accuracy: 0.9800
# Epoch 28/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0968 - val_accuracy: 0.9811
# Epoch 29/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.1278 - val_accuracy: 0.9745
# Epoch 30/35
# 118/118 [==============================] - 1s 13ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.1030 - val_accuracy: 0.9793
# Epoch 31/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.1021 - val_accuracy: 0.9808
# Epoch 32/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.1037 - val_accuracy: 0.9810
# Epoch 33/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.1069 - val_accuracy: 0.9791
# Epoch 34/35
# 118/118 [==============================] - 1s 13ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.1166 - val_accuracy: 0.9777
# Epoch 35/35
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.1006 - val_accuracy: 0.9799

# %% [markdown]
# ### Dibujar las curvas de entrenamiento/validación

# %%
def plot_curves(history):
  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Error')
  plt.plot(history['loss'])
  plt.plot(history['val_loss'])
  plt.legend(['Entrenamiento', 'Validación'])

  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Accuracy')
  plt.plot(history['accuracy'])
  plt.plot(history['val_accuracy'])
  plt.legend(['Entrenamiento', 'Validación'], loc='lower right');

plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
def plot_weights(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 11))
  cnt = 1
  for layer in layers:
      plt.subplot(1, n_img_show, cnt)
      plt.imshow(layer.get_weights()[0])
      plt.title(f'Pesos capa {cnt}')
      plt.colorbar(fraction=0.07)
      cnt += 1

def plot_weights_hist(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 5))
  cnt = 1
  for layer in layers:
    if layer.name.startswith('dense'):
      plt.subplot(1, n_img_show, cnt)
      plt.hist(layer.get_weights()[0].flatten(), bins=30)
      plt.title(f'Pesos capa {cnt}')
      mean = np.mean(layer.get_weights()[0])
      std = np.std(layer.get_weights()[0])
      plt.xlabel(f'Valores de los pesos. Media: {mean:.3f} +- {std:.3f}')
      plt.ylabel('cuenta')
      cnt +=1

plot_weights(model)
plot_weights_hist(model)

# %% [markdown]
# ## Regularización del modelo con L2
# Crea un modelo nuevo exactamente igual que el anterior y añade regularización L2 en todas las capas (menos en la de salida, como es obvio). Prueba distintos valores (0.1, 0.01 y 0.001) y observa cual es el comportamiento.

# %%
tf.keras.backend.clear_session()
n_epochs = 50
regularizer=tf.keras.regularizers.l2(0.01)

# Crear modelo
#    .
#    .
model_with_l2 = tf.keras.models.Sequential()
model_with_l2.add(tf.keras.layers.Dense(units=256, activation='relu', input_shape = (X_train.shape[1],), kernel_regularizer=regularizer))
model_with_l2.add(tf.keras.layers.Dense(128,       activation='relu', kernel_regularizer=regularizer))
model_with_l2.add(tf.keras.layers.Dense(64,        activation='relu', kernel_regularizer=regularizer))
model_with_l2.add(tf.keras.layers.Dense(32,        activation='relu', kernel_regularizer=regularizer))
model_with_l2.add(tf.keras.layers.Dense(10,        activation='softmax'))

# Compilamos el modelo
model_with_l2.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Entrenamos
hist = model_with_l2.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1,
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 2s 15ms/step - loss: 1.6555 - accuracy: 0.8462 - val_loss: 0.8731 - val_accuracy: 0.9073
# Epoch 2/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.8136 - accuracy: 0.9147 - val_loss: 0.7550 - val_accuracy: 0.9197
# Epoch 3/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.7274 - accuracy: 0.9240 - val_loss: 0.7016 - val_accuracy: 0.9249
# Epoch 4/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.6770 - accuracy: 0.9304 - val_loss: 0.6789 - val_accuracy: 0.9253
# Epoch 5/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.6478 - accuracy: 0.9334 - val_loss: 0.6167 - val_accuracy: 0.9371
# Epoch 6/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.6165 - accuracy: 0.9386 - val_loss: 0.6343 - val_accuracy: 0.9233
# Epoch 7/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.6002 - accuracy: 0.9390 - val_loss: 0.5776 - val_accuracy: 0.9423
# Epoch 8/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.5778 - accuracy: 0.9436 - val_loss: 0.5971 - val_accuracy: 0.9359
# Epoch 9/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.5703 - accuracy: 0.9431 - val_loss: 0.5591 - val_accuracy: 0.9414
# Epoch 10/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.5562 - accuracy: 0.9452 - val_loss: 0.5481 - val_accuracy: 0.9454
# Epoch 11/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.5449 - accuracy: 0.9469 - val_loss: 0.5529 - val_accuracy: 0.9389
# Epoch 12/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.5361 - accuracy: 0.9477 - val_loss: 0.5268 - val_accuracy: 0.9479
# Epoch 13/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.5272 - accuracy: 0.9489 - val_loss: 0.5150 - val_accuracy: 0.9495
# Epoch 14/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.5174 - accuracy: 0.9499 - val_loss: 0.5238 - val_accuracy: 0.9463
# Epoch 15/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.5100 - accuracy: 0.9506 - val_loss: 0.4961 - val_accuracy: 0.9539
# Epoch 16/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4999 - accuracy: 0.9529 - val_loss: 0.5045 - val_accuracy: 0.9500
# Epoch 17/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4973 - accuracy: 0.9520 - val_loss: 0.4837 - val_accuracy: 0.9539
# Epoch 18/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4898 - accuracy: 0.9528 - val_loss: 0.4827 - val_accuracy: 0.9543
# Epoch 19/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4840 - accuracy: 0.9547 - val_loss: 0.4757 - val_accuracy: 0.9546
# Epoch 20/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4783 - accuracy: 0.9552 - val_loss: 0.4748 - val_accuracy: 0.9528
# Epoch 21/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4757 - accuracy: 0.9547 - val_loss: 0.4689 - val_accuracy: 0.9539
# Epoch 22/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4682 - accuracy: 0.9553 - val_loss: 0.4613 - val_accuracy: 0.9550
# Epoch 23/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4651 - accuracy: 0.9557 - val_loss: 0.4530 - val_accuracy: 0.9569
# Epoch 24/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4590 - accuracy: 0.9560 - val_loss: 0.4487 - val_accuracy: 0.9563
# Epoch 25/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4562 - accuracy: 0.9574 - val_loss: 0.4580 - val_accuracy: 0.9537
# Epoch 26/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4515 - accuracy: 0.9571 - val_loss: 0.4591 - val_accuracy: 0.9525
# Epoch 27/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.4493 - accuracy: 0.9571 - val_loss: 0.4388 - val_accuracy: 0.9589
# Epoch 28/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4450 - accuracy: 0.9578 - val_loss: 0.4438 - val_accuracy: 0.9571
# Epoch 29/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4409 - accuracy: 0.9584 - val_loss: 0.4614 - val_accuracy: 0.9485
# Epoch 30/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.4395 - accuracy: 0.9584 - val_loss: 0.4419 - val_accuracy: 0.9553
# Epoch 31/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4367 - accuracy: 0.9582 - val_loss: 0.4327 - val_accuracy: 0.9573
# Epoch 32/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4336 - accuracy: 0.9586 - val_loss: 0.4358 - val_accuracy: 0.9535
# Epoch 33/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.4268 - accuracy: 0.9601 - val_loss: 0.4258 - val_accuracy: 0.9589
# Epoch 34/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.4240 - accuracy: 0.9598 - val_loss: 0.4220 - val_accuracy: 0.9595
# Epoch 35/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4251 - accuracy: 0.9592 - val_loss: 0.4324 - val_accuracy: 0.9557
# Epoch 36/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4234 - accuracy: 0.9589 - val_loss: 0.4235 - val_accuracy: 0.9584
# Epoch 37/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.4181 - accuracy: 0.9609 - val_loss: 0.4226 - val_accuracy: 0.9560
# Epoch 38/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.4161 - accuracy: 0.9604 - val_loss: 0.4169 - val_accuracy: 0.9596
# Epoch 39/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4162 - accuracy: 0.9604 - val_loss: 0.4118 - val_accuracy: 0.9597
# Epoch 40/50
# 118/118 [==============================] - 2s 14ms/step - loss: 0.4118 - accuracy: 0.9607 - val_loss: 0.4031 - val_accuracy: 0.9628
# Epoch 41/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4070 - accuracy: 0.9618 - val_loss: 0.3973 - val_accuracy: 0.9630
# Epoch 42/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4074 - accuracy: 0.9613 - val_loss: 0.4169 - val_accuracy: 0.9576
# Epoch 43/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4024 - accuracy: 0.9627 - val_loss: 0.4031 - val_accuracy: 0.9601
# Epoch 44/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4018 - accuracy: 0.9615 - val_loss: 0.4248 - val_accuracy: 0.9524
# Epoch 45/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.4003 - accuracy: 0.9616 - val_loss: 0.3961 - val_accuracy: 0.9614
# Epoch 46/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.3988 - accuracy: 0.9619 - val_loss: 0.4113 - val_accuracy: 0.9595
# Epoch 47/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.3986 - accuracy: 0.9614 - val_loss: 0.3976 - val_accuracy: 0.9610
# Epoch 48/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.3924 - accuracy: 0.9633 - val_loss: 0.3933 - val_accuracy: 0.9614
# Epoch 49/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.3893 - accuracy: 0.9638 - val_loss: 0.4021 - val_accuracy: 0.9562
# Epoch 50/50
# 118/118 [==============================] - 2s 13ms/step - loss: 0.3901 - accuracy: 0.9631 - val_loss: 0.3902 - val_accuracy: 0.9611

# %% [markdown]
# ### Evaluación del modelo con regularización L2

# %%
plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
plot_weights(model_with_l2)
plot_weights_hist(model_with_l2)

# %% [markdown]
# ## Regularización del modelo con Dropout
# Ahora crea el mismo modelo pero añade dropout. Prueba distintos valores de dropout.

# %%
tf.keras.backend.clear_session()

# Crear modelo
n_epochs = 25
#    .
#    .
model_with_dp = tf.keras.models.Sequential()

model_with_dp.add(tf.keras.layers.Dense(units=256, activation='relu', input_shape = (X_train.shape[1],)))
model_with_dp.add(Dropout(0.4))

model_with_dp.add(tf.keras.layers.Dense(128,       activation='relu'))
model_with_dp.add(Dropout(0.4))

model_with_dp.add(tf.keras.layers.Dense(64,        activation='relu'))
model_with_dp.add(Dropout(0.4))

model_with_dp.add(tf.keras.layers.Dense(32,        activation='relu'))
model_with_dp.add(Dropout(0.4))

model_with_dp.add(tf.keras.layers.Dense(10,        activation='softmax'))

# Compilamos el modelo
model_with_dp.compile(loss='sparse_categorical_crossentropy',
                      optimizer=optimizer,
                      metrics=['accuracy'])

# Entrenamos
hist = model_with_dp.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1, 
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.9235 - accuracy: 0.6948 - val_loss: 0.2354 - val_accuracy: 0.9385
# Epoch 2/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.3952 - accuracy: 0.9000 - val_loss: 0.1701 - val_accuracy: 0.9540
# Epoch 3/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.3089 - accuracy: 0.9251 - val_loss: 0.1591 - val_accuracy: 0.9577
# Epoch 4/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.2701 - accuracy: 0.9355 - val_loss: 0.1423 - val_accuracy: 0.9643
# Epoch 5/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.2395 - accuracy: 0.9419 - val_loss: 0.1345 - val_accuracy: 0.9683
# Epoch 6/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.2249 - accuracy: 0.9452 - val_loss: 0.1230 - val_accuracy: 0.9713
# Epoch 7/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.2068 - accuracy: 0.9500 - val_loss: 0.1200 - val_accuracy: 0.9725
# Epoch 8/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1927 - accuracy: 0.9543 - val_loss: 0.1152 - val_accuracy: 0.9727
# Epoch 9/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1840 - accuracy: 0.9546 - val_loss: 0.1141 - val_accuracy: 0.9738
# Epoch 10/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1791 - accuracy: 0.9574 - val_loss: 0.1105 - val_accuracy: 0.9733
# Epoch 11/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1629 - accuracy: 0.9597 - val_loss: 0.1099 - val_accuracy: 0.9756
# Epoch 12/25
# 118/118 [==============================] - 2s 16ms/step - loss: 0.1579 - accuracy: 0.9617 - val_loss: 0.1104 - val_accuracy: 0.9743
# Epoch 13/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1579 - accuracy: 0.9621 - val_loss: 0.1098 - val_accuracy: 0.9753
# Epoch 14/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1483 - accuracy: 0.9644 - val_loss: 0.1074 - val_accuracy: 0.9762
# Epoch 15/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1428 - accuracy: 0.9657 - val_loss: 0.1022 - val_accuracy: 0.9770
# Epoch 16/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1439 - accuracy: 0.9660 - val_loss: 0.1081 - val_accuracy: 0.9781
# Epoch 17/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1376 - accuracy: 0.9663 - val_loss: 0.1078 - val_accuracy: 0.9767
# Epoch 18/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1351 - accuracy: 0.9678 - val_loss: 0.1067 - val_accuracy: 0.9775
# Epoch 19/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1270 - accuracy: 0.9685 - val_loss: 0.1025 - val_accuracy: 0.9778
# Epoch 20/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1300 - accuracy: 0.9690 - val_loss: 0.1046 - val_accuracy: 0.9780
# Epoch 21/25
# 118/118 [==============================] - 2s 16ms/step - loss: 0.1269 - accuracy: 0.9693 - val_loss: 0.1051 - val_accuracy: 0.9783
# Epoch 22/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1188 - accuracy: 0.9706 - val_loss: 0.1062 - val_accuracy: 0.9779
# Epoch 23/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1182 - accuracy: 0.9711 - val_loss: 0.1032 - val_accuracy: 0.9795
# Epoch 24/25
# 118/118 [==============================] - 2s 16ms/step - loss: 0.1182 - accuracy: 0.9724 - val_loss: 0.1053 - val_accuracy: 0.9778
# Epoch 25/25
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1161 - accuracy: 0.9711 - val_loss: 0.1113 - val_accuracy: 0.9779

# %% [markdown]
# ### Evaluación del modelo con Dropout

# %%
# Plots
plot_curves(hist.history)
# plot_weights(model_with_dp)
plot_weights_hist(model_with_dp)
