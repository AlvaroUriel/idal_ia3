# %% [markdown]
# <a href="https://colab.research.google.com/github/AlvaroUriel/idal_ia3/blob/main/tfm_v0_6_051122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from  google.colab import drive
 
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#Imports
from tensorflow import keras
import matplotlib.pyplot as plt; 
import matplotlib.patches as patches
from tensorflow.keras.utils import load_img
import xml.etree.ElementTree as ET

# Keras
from tensorflow import keras
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
from keras.models import Sequential
from keras.applications import imagenet_utils
from tensorflow.keras.utils import load_img, img_to_array
from keras.layers import Input, Dense, Dropout, GlobalAveragePooling2D
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import image_dataset_from_directory

import cv2
from google.colab.patches import cv2_imshow

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt; 
import matplotlib.image as img
from numpy.core.fromnumeric import argmax

# %% [markdown]
# ##Data analysis

# %%
test_img_path = '/content/drive/MyDrive/IA3/TFM/archive/images/BikesHelmets0.png'
test_dat_path = '/content/drive/MyDrive/IA3/TFM/archive/annotations/BikesHelmets0.xml'

# %%
#image = load_img(test_img_path)
#plt.imshow(image) 

cv2_imshow(cv2.imread(test_img_path))
# Out:
# <PIL.Image.Image image mode=RGB size=400x267 at 0x7F1DFD602C50>

# %%
xml_file = open(test_dat_path)
print(xml_file.read())
# Out:
# <annotation>
#     <folder>images</folder>
#     <filename>BikesHelmets0.png</filename>
#     <size>
#         <width>400</width>
#         <height>267</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#     <object>
#         <name>With Helmet</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>29</xmin>
#             <ymin>105</ymin>
#             <xmax>82</xmax>
#             <ymax>160</ymax>
#         </bndbox>
#     </object>
#     <object>
#         <name>With Helmet</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>122</xmin>
#             <ymin>66</ymin>
#             <xmax>193</xmax>
#             <ymax>154</ymax>
#         </bndbox>
#     </object>
#     <object>
#         <name>With Helmet</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>201</xmin>
#             <ymin>43</ymin>
#             <xmax>246</xmax>
#             <ymax>98</ymax>
#         </bndbox>
#     </object>
#     <object>
#         <name>With Helmet</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>307</xmin>
#             <ymin>17</ymin>
#             <xmax>371</xmax>
#             <ymax>107</ymax>
#         </bndbox>
#     </object>
# </annotation>

# %%
# Create figure and axes
fig, ax = plt.subplots()

# Display the image
image = load_img(test_img_path)
ax.imshow(image)

tree=ET.parse(test_dat_path)

for element in tree.findall('object'):

    xmin = int(element.find("bndbox").find('xmin').text)
    ymin = int(element.find("bndbox").find('ymin').text)
    xmax = int(element.find("bndbox").find('xmax').text)
    ymax = int(element.find("bndbox").find('ymax').text)

    h = ymax - ymin
    w = xmax - xmin

    # Create a Rectangle patch
    rect = patches.Rectangle((int(xmin), int(ymin)), int(w), int(h), linewidth=1, edgecolor='r', facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)

plt.show()

# %%
#Example of cropped bounding boxes
tree=ET.parse(test_dat_path)

# Create figure and axes
img = cv2.imread(test_img_path)

for element in tree.findall('object'):

    xmin = int(element.find("bndbox").find('xmin').text)
    ymin = int(element.find("bndbox").find('ymin').text)
    xmax = int(element.find("bndbox").find('xmax').text)
    ymax = int(element.find("bndbox").find('ymax').text)

    h = ymax - ymin
    w = xmax - xmin

    # Cropping an image
    cropped_image = img[ymin:ymax, xmin:xmax, ]
    
    # Display cropped image
    cv2_imshow(cropped_image)

    plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=53x55 at 0x7F1DE866B890>
# <PIL.Image.Image image mode=RGB size=71x88 at 0x7F1E63978F90>
# <PIL.Image.Image image mode=RGB size=45x55 at 0x7F1DE866BDD0>
# <PIL.Image.Image image mode=RGB size=64x90 at 0x7F1DE866BDD0>

# %% [markdown]
# ##Data preprocessing

# %%
bCropImages = 0
if(bCropImages):

  img_path      = '/content/drive/MyDrive/IA3/TFM/archive/images/'
  xml_path      = '/content/drive/MyDrive/IA3/TFM/archive/annotations/'
  img_crop_path = '/content/drive/MyDrive/IA3/TFM/archive/croppedImages0/'
  cont=[0,0]
  cont_element = 0

  contenido = os.listdir(img_path)

  for fichero in contenido:
    if fichero.endswith('.png'):
      
      img = cv2.imread(img_path+fichero)
      tree=ET.parse(xml_path+fichero[:-3]+'xml')

      cont_element = 0

      for element in tree.findall('object'):

        clase = int(np.invert('Without' in element.find("name").text))
        xmin = int(element.find("bndbox").find('xmin').text)
        ymin = int(element.find("bndbox").find('ymin').text)
        xmax = int(element.find("bndbox").find('xmax').text)
        ymax = int(element.find("bndbox").find('ymax').text)

        h = ymax - ymin
        w = xmax - xmin

        # Cropping an image
        cropped_image = img[ymin:ymax, xmin:xmax]

        if cropped_image.shape[0]==0 and cropped_image.shape[1]==0:
          print(fichero + ' object: ' + str(cont_element) + ' is empty!')
        else:
          cv2.imwrite(img_crop_path + str(clase) + '_' + str(cont[clase]) + '_' + fichero[:-4] + '.png', cropped_image)
          cont[clase] = cont[clase] + 1
        
        cont_element = cont_element +1

# %%
#Visual correction of labels

wrong_label_images =['BikesHelmets78.',
                     'BikesHelmets601.',
                     'BikesHelmets573.',
                     'BikesHelmets517.',
                     'BikesHelmets424.',
                     'BikesHelmets375.',
                     'BikesHelmets291.',
                     'BikesHelmets154.',
                     'BikesHelmets752.',
                     'BikesHelmets186.',
                     'BikesHelmets182.',
                     'BikesHelmets45.',
                     'BikesHelmets296.',
                     'BikesHelmets281.',
                     'BikesHelmets446.']
wrong_label_images
# Out:
# ['BikesHelmets78.',
#  'BikesHelmets601.',
#  'BikesHelmets573.',
#  'BikesHelmets517.',
#  'BikesHelmets424.',
#  'BikesHelmets375.',
#  'BikesHelmets291.',
#  'BikesHelmets154.',
#  'BikesHelmets752.',
#  'BikesHelmets186.',
#  'BikesHelmets182.',
#  'BikesHelmets45.',
#  'BikesHelmets296.',
#  'BikesHelmets281.',
#  'BikesHelmets446.']

# %%
#Red rectangles means labeled as helmet, green ones as no helmet

img_path      = '/content/drive/MyDrive/IA3/TFM/archive/images/'
xml_path      = '/content/drive/MyDrive/IA3/TFM/archive/annotations/'
img_crop_path = '/content/drive/MyDrive/IA3/TFM/archive/croppedImages0/'

for my_img in wrong_label_images:

  # Create figure and axes
  fig, ax = plt.subplots()

  # Display the image

  image = load_img(img_path+my_img+'png')
  ax.imshow(image)

  tree=ET.parse(xml_path+my_img+'xml')

  for element in tree.findall('object'):

      if('With Helmet' in element.find("name").text):
        colorHelmet = 'r'
      else:
        colorHelmet = 'g'

      xmin = int(element.find("bndbox").find('xmin').text)
      ymin = int(element.find("bndbox").find('ymin').text)
      xmax = int(element.find("bndbox").find('xmax').text)
      ymax = int(element.find("bndbox").find('ymax').text)

      h = ymax - ymin
      w = xmax - xmin

      # Create a Rectangle patch
      rect = patches.Rectangle((int(xmin), int(ymin)), int(w), int(h), linewidth=2, edgecolor=colorHelmet, facecolor='none')

      # Add the patch to the Axes
      ax.add_patch(rect)

  plt.show()

# %%
bCropImages = 0
if(bCropImages):

  img_path      = '/content/drive/MyDrive/IA3/TFM/archive/images/'
  xml_path      = '/content/drive/MyDrive/IA3/TFM/archive/annotations/'
  img_crop_path = '/content/drive/MyDrive/IA3/TFM/archive/croppedImages1/'
  cont=[0,0]
  cont_element = 0

  contenido = os.listdir(img_path)

  for fichero in contenido:
    
    if fichero[:-3] in wrong_label_images:
      print('Omitida:' + fichero) 
    else:
      if fichero.endswith('.png'):
        
        img = cv2.imread(img_path+fichero)
        tree=ET.parse(xml_path+fichero[:-3]+'xml')

        cont_element = 0

        for element in tree.findall('object'):

          clase = int(np.invert('Without' in element.find("name").text))
          xmin = int(element.find("bndbox").find('xmin').text)
          ymin = int(element.find("bndbox").find('ymin').text)
          xmax = int(element.find("bndbox").find('xmax').text)
          ymax = int(element.find("bndbox").find('ymax').text)

          h = ymax - ymin
          w = xmax - xmin

          # Cropping an image
          cropped_image = img[ymin:ymax, xmin:xmax]

          if cropped_image.shape[0]==0 and cropped_image.shape[1]==0:
            print(fichero + ' object: ' + str(cont_element) + ' is empty!')
          else:
#           cv2.imwrite(img_crop_path + str(clase) + '_' + str(cont[clase]) + '_' + fichero[:-4] + '.png', cropped_image)
            if(h<24) or (w<24):
              print(fichero + ' object: ' + str(cont_element) + ' is too small!')
            else:
              cv2.imwrite(img_crop_path + str(clase) + '__' + str(cont[clase]) + '_' + fichero[:-4] + '.png', cropped_image)
              cont[clase] = cont[clase] + 1
          
          cont_element = cont_element +1

# %%
##test augmentation
from keras.utils.image_utils import array_to_img
from matplotlib.pyplot import imshow

image = cv2.imread(test_img_path)
image=cv2.flip(image, 2)
cv2_imshow(image)
cv2.imwrite
# Out:
# <PIL.Image.Image image mode=RGB size=400x267 at 0x7F1DE7D83810>
# <function imwrite>

# %% [markdown]
# ##Data augmentation

# %%
bFlipImages = 0
img_path = '/content/drive/MyDrive/IA3/TFM/archive/croppedImages1/'
img_path_out = '/content/drive/MyDrive/IA3/TFM/archive/croppedImagesAug/'

if(bFlipImages):

  for fichero in os.listdir(img_path):
    img = cv2.imread(img_path+fichero)
    imgFlip = cv2.flip(img, 2)
    cv2.imwrite(img_path_out+fichero[:-4]+'_orig'+'.png', img)
    cv2.imwrite(img_path_out+fichero[:-4]+'_flip'+'.png', imgFlip)

print('cropped images: ', len(os.listdir(img_path)))
print('augment images: ', len(os.listdir(img_path_out)))
# Out:
# cropped images:  1100
# augment images:  2200

# %% [markdown]
# ##Training

# %%
data_path = '/content/drive/MyDrive/IA3/TFM/archive/croppedImagesAug/'

#Creamos listas con todos los nombres de los ficheros 
data_0=[]
data_1=[]

for img in os.listdir(data_path):
  if '0__' in img:
    data_0.append(os.path.join(data_path,img))
  else:
    data_1.append(os.path.join(data_path,img))

print(len(os.listdir(data_path)), len(data_0), len(data_1), len(data_0) + len(data_1))
# Out:
# 2200 624 1576 2200

# %%
from sklearn.model_selection import train_test_split

train_0, test_0 = train_test_split(data_0, test_size=0.4)
test_0, val_0 = train_test_split(test_0, test_size=0.5)

print(len(data_0), len(train_0), len(test_0), len(val_0))

train_1, test_1 = train_test_split(data_1, test_size=0.4)
test_1, val_1 = train_test_split(test_1, test_size=0.5)

print(len(data_1), len(train_1), len(test_1), len(val_1))
# Out:
# 624 374 125 125
# 1576 945 315 316

# %%
train_0[0:3]
# Out:
# ['/content/drive/MyDrive/IA3/TFM/archive/croppedImagesAug/0__53_BikesHelmets297_flip.png',
#  '/content/drive/MyDrive/IA3/TFM/archive/croppedImagesAug/0__76_BikesHelmets331_orig.png',
#  '/content/drive/MyDrive/IA3/TFM/archive/croppedImagesAug/0__26_BikesHelmets176_orig.png']

# %%
train_1[0:3]
# Out:
# ['/content/drive/MyDrive/IA3/TFM/archive/croppedImagesAug/1__764_BikesHelmets85_orig.png',
#  '/content/drive/MyDrive/IA3/TFM/archive/croppedImagesAug/1__502_BikesHelmets515_orig.png',
#  '/content/drive/MyDrive/IA3/TFM/archive/croppedImagesAug/1__766_BikesHelmets97_flip.png']

# %%
num_classes = 2
y = []

for img in train_0:
  y.append(0) 

y_train_0 = np_utils.to_categorical(y, num_classes)

# %%
y = []

for img in train_1:
  y.append(1) 

y_train_1 = np_utils.to_categorical(y, num_classes)

# %%
y = []

for img in test_0:
  y.append(0) 

y_test_0 = np_utils.to_categorical(y, num_classes)

# %%
y = []

for img in test_1:
  y.append(1) 

y_test_1 = np_utils.to_categorical(y, num_classes)

# %%
y = []

for img in val_0:
  y.append(0) 

y_val_0 = np_utils.to_categorical(y, num_classes)

# %%
y = []

for img in val_1:
  y.append(1) 

y_val_1 = np_utils.to_categorical(y, num_classes)

# %%
y_train = np.concatenate([y_train_0, y_train_1])
y_test = np.concatenate([y_test_0, y_test_1])
y_val = np.concatenate([y_val_0, y_val_1])
print(y_train.shape)
print(y_test.shape)
print(y_val.shape)
# Out:
# (1319, 2)
# (440, 2)
# (441, 2)

# %%
train = train_0 + train_1
test = test_0 + test_1
val = val_0 + val_1
print(len(train))
print(len(test))
print(len(val))
# Out:
# 1319
# 440
# 441

# %%
#Clase para mostrar imagenes
def show_imgs(X):
    plt.figure(figsize=(14, 14))
    k = 0
    #k= np.random.randint(0, len(X)-1-16)

    for i in range(0,4):
        for j in range(0,4):
            image = load_img(train[k], target_size=(224, 224))
            ax = plt.subplot2grid((4,4),(i,j))
            #ax.set_title('Clase: ' + str(y_train[k]) ) 
            if(y_train[k][0]):
              ax.set_title('Clase: ' + str(y_train[k]) + ' Without Helment') 
            else:
              ax.set_title('Clase: ' + str(y_train[k]) + ' With Helment') 
            plt.subplots_adjust(hspace=0.5)    
            plt.imshow(image)            
            #k = k+1
            k= np.random.randint(0, len(X)-1-16)
    #Muestra
    plt.show()

# %%
show_imgs(train)

# %%
def create_features(dataset):
 
    x_scratch = []

    k=0

    #Bucle sobre las imagenes
    for imagePath in dataset:
 
        #Se cargan las imagenes a tamaño 224
        image = load_img(imagePath, target_size=(224, 224))
        image = img_to_array(image)
 
        # preprocess the image by (1) expanding the dimensions and
        # (2) subtracting the mean RGB pixel intensity from the
        # ImageNet dataset
        image = np.expand_dims(image, axis=0)
        image = imagenet_utils.preprocess_input(image)
 
        # add the image to the batch
        x_scratch.append(image)

        k = k+1
        #print('convertida:', k, ' de ', len(dataset))
 
    x = np.vstack(x_scratch)
    return x

# %%
train_x = create_features(train)
val_x = create_features(val)
test_x = create_features(test)
print(train_x.shape)
print(val_x.shape)
print(test_x.shape)
# Out:
# (1319, 224, 224, 3)
# (441, 224, 224, 3)
# (440, 224, 224, 3)

# %%
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, GlobalAveragePooling2D

model = Sequential()
model.add(Conv2D(16, (3,3), activation='relu', input_shape=train_x.shape[1:]))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())

model.add(Dropout(0.5))
model.add(Dense(100, activation='relu', kernel_regularizer="l2")) # regularizador L2
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

opt = Adam(learning_rate=0.00001)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 222, 222, 16)      448
#
#  max_pooling2d_6 (MaxPooling  (None, 111, 111, 16)     0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 109, 109, 32)      4640
#
#  max_pooling2d_7 (MaxPooling  (None, 54, 54, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 52, 52, 64)        18496
#
#  max_pooling2d_8 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 43264)             0
#
#  dropout_4 (Dropout)         (None, 43264)             0
#
#  dense_4 (Dense)             (None, 100)               4326500
#
#  dropout_5 (Dropout)         (None, 100)               0
#
#  dense_5 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 4,350,286
# Trainable params: 4,350,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
display(SVG(model_to_dot(model, show_shapes=True,dpi=72).create(prog='dot', format='svg')))

# %%
checkpointer = ModelCheckpoint(filepath='model.best.hdf5',
                               verbose=1,save_best_only=True)

# %%
history = model.fit(train_x, y_train, batch_size=32, epochs=50,
          validation_data=(val_x, y_val), callbacks=[checkpointer],verbose=1, shuffle=True)
# Out:
# Epoch 1/50
# 41/42 [============================>.] - ETA: 0s - loss: 15.8526 - accuracy: 0.6174
# Epoch 1: val_loss improved from inf to 4.79036, saving model to model.best.hdf5
# 42/42 [==============================] - 3s 51ms/step - loss: 15.8090 - accuracy: 0.6179 - val_loss: 4.7904 - val_accuracy: 0.7415
# Epoch 2/50
# 41/42 [============================>.] - ETA: 0s - loss: 7.6117 - accuracy: 0.6822
# Epoch 2: val_loss improved from 4.79036 to 2.96471, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 7.6405 - accuracy: 0.6808 - val_loss: 2.9647 - val_accuracy: 0.7778
# Epoch 3/50
# 41/42 [============================>.] - ETA: 0s - loss: 5.2943 - accuracy: 0.6959
# Epoch 3: val_loss improved from 2.96471 to 2.51696, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 5.2771 - accuracy: 0.6975 - val_loss: 2.5170 - val_accuracy: 0.7959
# Epoch 4/50
# 41/42 [============================>.] - ETA: 0s - loss: 3.8459 - accuracy: 0.7111
# Epoch 4: val_loss improved from 2.51696 to 2.38980, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 44ms/step - loss: 3.8605 - accuracy: 0.7104 - val_loss: 2.3898 - val_accuracy: 0.7914
# Epoch 5/50
# 41/42 [============================>.] - ETA: 0s - loss: 3.2084 - accuracy: 0.7012
# Epoch 5: val_loss improved from 2.38980 to 2.37995, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 3.2079 - accuracy: 0.7013 - val_loss: 2.3800 - val_accuracy: 0.7846
# Epoch 6/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.8730 - accuracy: 0.7218
# Epoch 6: val_loss did not improve from 2.37995
# 42/42 [==============================] - 2s 40ms/step - loss: 2.8733 - accuracy: 0.7210 - val_loss: 2.4086 - val_accuracy: 0.8050
# Epoch 7/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.6638 - accuracy: 0.7287
# Epoch 7: val_loss did not improve from 2.37995
# 42/42 [==============================] - 2s 39ms/step - loss: 2.6611 - accuracy: 0.7301 - val_loss: 2.3954 - val_accuracy: 0.7415
# Epoch 8/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.5686 - accuracy: 0.7317
# Epoch 8: val_loss did not improve from 2.37995
# 42/42 [==============================] - 2s 39ms/step - loss: 2.5664 - accuracy: 0.7324 - val_loss: 2.4022 - val_accuracy: 0.7914
# Epoch 9/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.5137 - accuracy: 0.7348
# Epoch 9: val_loss improved from 2.37995 to 2.37929, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 44ms/step - loss: 2.5118 - accuracy: 0.7346 - val_loss: 2.3793 - val_accuracy: 0.7415
# Epoch 10/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.5168 - accuracy: 0.7218
# Epoch 10: val_loss improved from 2.37929 to 2.35437, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.5153 - accuracy: 0.7225 - val_loss: 2.3544 - val_accuracy: 0.7415
# Epoch 11/50
# 42/42 [==============================] - ETA: 0s - loss: 2.4380 - accuracy: 0.7437
# Epoch 11: val_loss improved from 2.35437 to 2.33463, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 50ms/step - loss: 2.4380 - accuracy: 0.7437 - val_loss: 2.3346 - val_accuracy: 0.7642
# Epoch 12/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.3964 - accuracy: 0.7523
# Epoch 12: val_loss improved from 2.33463 to 2.32508, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 54ms/step - loss: 2.3947 - accuracy: 0.7536 - val_loss: 2.3251 - val_accuracy: 0.7710
# Epoch 13/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.3827 - accuracy: 0.7340
# Epoch 13: val_loss improved from 2.32508 to 2.30947, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 53ms/step - loss: 2.3809 - accuracy: 0.7354 - val_loss: 2.3095 - val_accuracy: 0.7574
# Epoch 14/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.3568 - accuracy: 0.7523
# Epoch 14: val_loss improved from 2.30947 to 2.29920, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.3568 - accuracy: 0.7528 - val_loss: 2.2992 - val_accuracy: 0.7619
# Epoch 15/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.3570 - accuracy: 0.7645
# Epoch 15: val_loss improved from 2.29920 to 2.27937, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 44ms/step - loss: 2.3567 - accuracy: 0.7642 - val_loss: 2.2794 - val_accuracy: 0.8005
# Epoch 16/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.3743 - accuracy: 0.7591
# Epoch 16: val_loss improved from 2.27937 to 2.26847, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.3732 - accuracy: 0.7597 - val_loss: 2.2685 - val_accuracy: 0.8141
# Epoch 17/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.3475 - accuracy: 0.7584
# Epoch 17: val_loss improved from 2.26847 to 2.25142, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.3512 - accuracy: 0.7589 - val_loss: 2.2514 - val_accuracy: 0.8277
# Epoch 18/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.2800 - accuracy: 0.7889
# Epoch 18: val_loss improved from 2.25142 to 2.23796, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 45ms/step - loss: 2.2834 - accuracy: 0.7877 - val_loss: 2.2380 - val_accuracy: 0.8299
# Epoch 19/50
# 40/42 [===========================>..] - ETA: 0s - loss: 2.2990 - accuracy: 0.7758
# Epoch 19: val_loss did not improve from 2.23796
# 42/42 [==============================] - 2s 40ms/step - loss: 2.2981 - accuracy: 0.7756 - val_loss: 2.2388 - val_accuracy: 0.8005
# Epoch 20/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.3036 - accuracy: 0.7706
# Epoch 20: val_loss improved from 2.23796 to 2.22876, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.3029 - accuracy: 0.7710 - val_loss: 2.2288 - val_accuracy: 0.8277
# Epoch 21/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.2734 - accuracy: 0.7858
# Epoch 21: val_loss improved from 2.22876 to 2.22090, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 44ms/step - loss: 2.2739 - accuracy: 0.7847 - val_loss: 2.2209 - val_accuracy: 0.8299
# Epoch 22/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.2526 - accuracy: 0.7752
# Epoch 22: val_loss improved from 2.22090 to 2.21337, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.2520 - accuracy: 0.7756 - val_loss: 2.2134 - val_accuracy: 0.8209
# Epoch 23/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.2652 - accuracy: 0.7851
# Epoch 23: val_loss did not improve from 2.21337
# 42/42 [==============================] - 2s 39ms/step - loss: 2.2658 - accuracy: 0.7839 - val_loss: 2.2153 - val_accuracy: 0.8277
# Epoch 24/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.2305 - accuracy: 0.7988
# Epoch 24: val_loss improved from 2.21337 to 2.21060, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 45ms/step - loss: 2.2337 - accuracy: 0.7976 - val_loss: 2.2106 - val_accuracy: 0.8254
# Epoch 25/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.2276 - accuracy: 0.7912
# Epoch 25: val_loss improved from 2.21060 to 2.20072, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.2270 - accuracy: 0.7923 - val_loss: 2.2007 - val_accuracy: 0.8209
# Epoch 26/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.2193 - accuracy: 0.7957
# Epoch 26: val_loss improved from 2.20072 to 2.19021, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.2214 - accuracy: 0.7945 - val_loss: 2.1902 - val_accuracy: 0.8277
# Epoch 27/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.2041 - accuracy: 0.8140
# Epoch 27: val_loss improved from 2.19021 to 2.18623, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 42ms/step - loss: 2.2043 - accuracy: 0.8127 - val_loss: 2.1862 - val_accuracy: 0.8231
# Epoch 28/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1854 - accuracy: 0.8255
# Epoch 28: val_loss improved from 2.18623 to 2.17434, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.1860 - accuracy: 0.8249 - val_loss: 2.1743 - val_accuracy: 0.8277
# Epoch 29/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1941 - accuracy: 0.8087
# Epoch 29: val_loss did not improve from 2.17434
# 42/42 [==============================] - 2s 39ms/step - loss: 2.1936 - accuracy: 0.8089 - val_loss: 2.1751 - val_accuracy: 0.8345
# Epoch 30/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1751 - accuracy: 0.8209
# Epoch 30: val_loss improved from 2.17434 to 2.15991, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 45ms/step - loss: 2.1754 - accuracy: 0.8203 - val_loss: 2.1599 - val_accuracy: 0.8299
# Epoch 31/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1879 - accuracy: 0.8087
# Epoch 31: val_loss improved from 2.15991 to 2.15953, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.1880 - accuracy: 0.8082 - val_loss: 2.1595 - val_accuracy: 0.8299
# Epoch 32/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1550 - accuracy: 0.8087
# Epoch 32: val_loss did not improve from 2.15953
# 42/42 [==============================] - 2s 39ms/step - loss: 2.1547 - accuracy: 0.8089 - val_loss: 2.1615 - val_accuracy: 0.8390
# Epoch 33/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1793 - accuracy: 0.8133
# Epoch 33: val_loss improved from 2.15953 to 2.15271, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 44ms/step - loss: 2.1805 - accuracy: 0.8127 - val_loss: 2.1527 - val_accuracy: 0.8299
# Epoch 34/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1510 - accuracy: 0.8232
# Epoch 34: val_loss did not improve from 2.15271
# 42/42 [==============================] - 2s 39ms/step - loss: 2.1549 - accuracy: 0.8218 - val_loss: 2.1546 - val_accuracy: 0.8390
# Epoch 35/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1722 - accuracy: 0.8224
# Epoch 35: val_loss improved from 2.15271 to 2.14049, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.1714 - accuracy: 0.8234 - val_loss: 2.1405 - val_accuracy: 0.8231
# Epoch 36/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1532 - accuracy: 0.8102
# Epoch 36: val_loss improved from 2.14049 to 2.13693, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.1532 - accuracy: 0.8097 - val_loss: 2.1369 - val_accuracy: 0.8231
# Epoch 37/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1378 - accuracy: 0.8232
# Epoch 37: val_loss improved from 2.13693 to 2.13188, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 44ms/step - loss: 2.1387 - accuracy: 0.8226 - val_loss: 2.1319 - val_accuracy: 0.8390
# Epoch 38/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1324 - accuracy: 0.8262
# Epoch 38: val_loss improved from 2.13188 to 2.13138, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.1309 - accuracy: 0.8271 - val_loss: 2.1314 - val_accuracy: 0.8322
# Epoch 39/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1228 - accuracy: 0.8232
# Epoch 39: val_loss improved from 2.13138 to 2.11658, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 44ms/step - loss: 2.1225 - accuracy: 0.8234 - val_loss: 2.1166 - val_accuracy: 0.8299
# Epoch 40/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1215 - accuracy: 0.8194
# Epoch 40: val_loss improved from 2.11658 to 2.11649, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.1211 - accuracy: 0.8196 - val_loss: 2.1165 - val_accuracy: 0.8254
# Epoch 41/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1128 - accuracy: 0.8277
# Epoch 41: val_loss improved from 2.11649 to 2.11111, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.1115 - accuracy: 0.8287 - val_loss: 2.1111 - val_accuracy: 0.8390
# Epoch 42/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.0989 - accuracy: 0.8316
# Epoch 42: val_loss improved from 2.11111 to 2.10615, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.0979 - accuracy: 0.8324 - val_loss: 2.1061 - val_accuracy: 0.8458
# Epoch 43/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.0917 - accuracy: 0.8399
# Epoch 43: val_loss improved from 2.10615 to 2.10345, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.0914 - accuracy: 0.8400 - val_loss: 2.1034 - val_accuracy: 0.8503
# Epoch 44/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.1094 - accuracy: 0.8346
# Epoch 44: val_loss improved from 2.10345 to 2.09977, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.1088 - accuracy: 0.8347 - val_loss: 2.0998 - val_accuracy: 0.8390
# Epoch 45/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.0784 - accuracy: 0.8338
# Epoch 45: val_loss improved from 2.09977 to 2.09070, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 42ms/step - loss: 2.0777 - accuracy: 0.8340 - val_loss: 2.0907 - val_accuracy: 0.8345
# Epoch 46/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.0590 - accuracy: 0.8544
# Epoch 46: val_loss improved from 2.09070 to 2.08924, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.0634 - accuracy: 0.8514 - val_loss: 2.0892 - val_accuracy: 0.8526
# Epoch 47/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.0921 - accuracy: 0.8338
# Epoch 47: val_loss improved from 2.08924 to 2.08687, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.0916 - accuracy: 0.8347 - val_loss: 2.0869 - val_accuracy: 0.8299
# Epoch 48/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.0635 - accuracy: 0.8445
# Epoch 48: val_loss improved from 2.08687 to 2.08355, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.0630 - accuracy: 0.8446 - val_loss: 2.0835 - val_accuracy: 0.8413
# Epoch 49/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.0800 - accuracy: 0.8346
# Epoch 49: val_loss improved from 2.08355 to 2.08006, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.0803 - accuracy: 0.8347 - val_loss: 2.0801 - val_accuracy: 0.8526
# Epoch 50/50
# 41/42 [============================>.] - ETA: 0s - loss: 2.0568 - accuracy: 0.8605
# Epoch 50: val_loss improved from 2.08006 to 2.07105, saving model to model.best.hdf5
# 42/42 [==============================] - 2s 43ms/step - loss: 2.0569 - accuracy: 0.8597 - val_loss: 2.0710 - val_accuracy: 0.8458

# %%
def plot_accuracy_loss(history):
    fig = plt.figure(figsize=(10,5))
 
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.ylim([0, 1])
 
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()
 
plot_accuracy_loss(history)

# %%
# Creating a checkpointer
checkpointer = ModelCheckpoint(filepath='scratchmodel.best.hdf5',
                               verbose=1,save_best_only=True)
# load the VGG16 network
print("[INFO loading network...")
model_vgg = VGG16(weights="imagenet", include_top=False, input_shape=train_x.shape[1:])
model_vgg.summary()
# Out:
# [INFO loading network...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 1s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Freeze the layers except the last 9 layers
#for layer in model_vgg.layers[:-9]:
    #layer.trainable = False
 
# Check the trainable status of the individual layers
for layer in model_vgg.layers:
    print(layer, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f1de72ce9d0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f1dd04d4210> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f1de73b4950> True
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f1dd0412450> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f1dd0415bd0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f1de7406e50> True
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f1de74244d0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f1de7406250> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f1de74062d0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f1de740bf90> True
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f1dd00335d0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f1dd04a6310> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f1de7145350> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f1de8034550> True
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f1de71f7c90> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f1de8034310> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f1de812b2d0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f1de70ac450> True
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f1de812ba10> True

# %%
model_transfer_full = Sequential()
model_transfer_full.add(model_vgg)
model_transfer_full.add(GlobalAveragePooling2D())
model_transfer_full.add(Dropout(0.2))
model_transfer_full.add(Dense(100, activation='relu'))
model_transfer_full.add(Dense(num_classes, activation='softmax'))
model_transfer_full.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 100)               51300
#
#  dense_7 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 14,766,190
# Trainable params: 14,766,190
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(learning_rate=0.00001)
model_transfer_full.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])
history = model_transfer_full.fit(train_x, y_train, batch_size=32, epochs=10,
          validation_data=(val_x, y_val), callbacks=[checkpointer],verbose=1, shuffle=True)
# Out:
# Epoch 1/10
# 42/42 [==============================] - ETA: 0s - loss: 0.6293 - accuracy: 0.7544
# Epoch 1: val_loss improved from inf to 0.35314, saving model to scratchmodel.best.hdf5
# 42/42 [==============================] - 35s 661ms/step - loss: 0.6293 - accuracy: 0.7544 - val_loss: 0.3531 - val_accuracy: 0.8367
# Epoch 2/10
# 42/42 [==============================] - ETA: 0s - loss: 0.2441 - accuracy: 0.8946
# Epoch 2: val_loss improved from 0.35314 to 0.24317, saving model to scratchmodel.best.hdf5
# 42/42 [==============================] - 21s 508ms/step - loss: 0.2441 - accuracy: 0.8946 - val_loss: 0.2432 - val_accuracy: 0.9070
# Epoch 3/10
# 42/42 [==============================] - ETA: 0s - loss: 0.1366 - accuracy: 0.9515
# Epoch 3: val_loss improved from 0.24317 to 0.17934, saving model to scratchmodel.best.hdf5
# 42/42 [==============================] - 21s 506ms/step - loss: 0.1366 - accuracy: 0.9515 - val_loss: 0.1793 - val_accuracy: 0.9229
# Epoch 4/10
# 42/42 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9636
# Epoch 4: val_loss did not improve from 0.17934
# 42/42 [==============================] - 21s 496ms/step - loss: 0.1081 - accuracy: 0.9636 - val_loss: 0.1949 - val_accuracy: 0.9161
# Epoch 5/10
# 42/42 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9613
# Epoch 5: val_loss did not improve from 0.17934
# 42/42 [==============================] - 21s 501ms/step - loss: 0.0878 - accuracy: 0.9613 - val_loss: 0.2418 - val_accuracy: 0.9320
# Epoch 6/10
# 42/42 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9833
# Epoch 6: val_loss improved from 0.17934 to 0.14979, saving model to scratchmodel.best.hdf5
# 42/42 [==============================] - 21s 509ms/step - loss: 0.0436 - accuracy: 0.9833 - val_loss: 0.1498 - val_accuracy: 0.9501
# Epoch 7/10
# 42/42 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9894
# Epoch 7: val_loss did not improve from 0.14979
# 42/42 [==============================] - 21s 496ms/step - loss: 0.0350 - accuracy: 0.9894 - val_loss: 0.1796 - val_accuracy: 0.9478
# Epoch 8/10
# 42/42 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9947
# Epoch 8: val_loss improved from 0.14979 to 0.14619, saving model to scratchmodel.best.hdf5
# 42/42 [==============================] - 21s 506ms/step - loss: 0.0234 - accuracy: 0.9947 - val_loss: 0.1462 - val_accuracy: 0.9478
# Epoch 9/10
# 42/42 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9955
# Epoch 9: val_loss improved from 0.14619 to 0.13243, saving model to scratchmodel.best.hdf5
# 42/42 [==============================] - 21s 510ms/step - loss: 0.0168 - accuracy: 0.9955 - val_loss: 0.1324 - val_accuracy: 0.9546
# Epoch 10/10
# 42/42 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9932
# Epoch 10: val_loss did not improve from 0.13243
# 42/42 [==============================] - 21s 501ms/step - loss: 0.0162 - accuracy: 0.9932 - val_loss: 0.1620 - val_accuracy: 0.9524

# %% [markdown]
# ##Test

# %%
def plot_accuracy_loss(history):
    fig = plt.figure(figsize=(10,5))
 
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.ylim([0, 1])
 
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()
 
plot_accuracy_loss(history)

# %%
test_y=[]

for i in y_test:
  test_y.append(np.argmax(i))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
preds = np.argmax(model_transfer_full.predict(test_x), axis=1)
print("\nAccuracy on Test Data: ", accuracy_score(test_y, preds))
print("\nNumber of correctly identified imgaes: ",
      accuracy_score(test_y, preds, normalize=False),"\n")
confusion_matrix(test_y, preds, labels=range(0,num_classes))
# Out:
# 14/14 [==============================] - 2s 163ms/step
#
# Accuracy on Test Data:  0.9568181818181818
#
# Number of correctly identified imgaes:  421
# array([[110,  15],
#        [  4, 311]])

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
y_pred_proba = model.predict(test_x)
y_pred = np.argmax(y_pred_proba, axis=1)
print('Model')
print(classification_report(test_y, y_pred))

clase_positiva = 1
#fpr, tpr, thresholds = roc_curve(test_y==clase_positiva, y_pred_proba[:,clase_positiva])
fpr, tpr, thresholds = roc_curve(test_y, y_pred_proba[:,clase_positiva])
fig, ax1 = plt.subplots(1,1)
ax1.plot(fpr, tpr, 'r-.', label = 'CNN (%2.2f)' % auc(fpr, tpr))
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.plot(fpr, fpr, 'b-', label = 'Random Guess')
ax1.legend();
# Out:
# 14/14 [==============================] - 0s 17ms/step
# Model
#               precision    recall  f1-score   support
#
#            0       0.89      0.63      0.74       125
#            1       0.87      0.97      0.92       315
#
#     accuracy                           0.87       440
#    macro avg       0.88      0.80      0.83       440
# weighted avg       0.87      0.87      0.87       440

# %%
y_pred_proba = model_transfer_full.predict(test_x)
y_pred = np.argmax(y_pred_proba, axis=1)
print('Model transfer')
print(classification_report(test_y, y_pred))

fpr, tpr, thresholds = roc_curve(test_y, y_pred_proba[:,clase_positiva])
fig, ax1 = plt.subplots(1,1)
ax1.plot(fpr, tpr, 'r-.', label = 'CNN (%2.2f)' % auc(fpr, tpr))
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.plot(fpr, fpr, 'b-', label = 'Random Guess')
ax1.legend();
# Out:
# 14/14 [==============================] - 2s 166ms/step
# Model transfer
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.92       125
#            1       0.95      0.99      0.97       315
#
#     accuracy                           0.96       440
#    macro avg       0.96      0.93      0.95       440
# weighted avg       0.96      0.96      0.96       440

# %%
scores_tr = model.evaluate(x=train_x, y=y_train)
print('Train loss    :', scores_tr[0])
print('Train accuracy:', scores_tr[1])
print()

scores_te = model.evaluate(x=test_x, y=y_test)
print('Test loss     :', scores_te[0])
print('Test accuracy :', scores_te[1])

scores_val = model.evaluate(x=val_x, y=y_val)
print('Val loss    :', scores_val[0])
print('Val accuracy:', scores_val[1])
print()
# Out:
# 42/42 [==============================] - 1s 19ms/step - loss: 1.9794 - accuracy: 0.8931
# Train loss    : 1.9794131517410278
# Train accuracy: 0.8931008577346802
#
# 14/14 [==============================] - 0s 20ms/step - loss: 2.0048 - accuracy: 0.8727
# Test loss     : 2.004784107208252
# Test accuracy : 0.8727272748947144
# 14/14 [==============================] - 0s 19ms/step - loss: 2.0710 - accuracy: 0.8458
# Val loss    : 2.071046829223633
# Val accuracy: 0.8458049893379211

# %%
scores_tr = model_transfer_full.evaluate(x=train_x, y=y_train)
print('Train loss    :', scores_tr[0])
print('Train accuracy:', scores_tr[1])
print()

scores_te = model_transfer_full.evaluate(x=test_x, y=y_test)
print('Test loss     :', scores_te[0])
print('Test accuracy :', scores_te[1])

scores_val = model_transfer_full.evaluate(x=val_x, y=y_val)
print('Val loss    :', scores_val[0])
print('Val accuracy:', scores_val[1])
print()
# Out:
# 42/42 [==============================] - 7s 164ms/step - loss: 0.0045 - accuracy: 0.9985
# Train loss    : 0.004480700474232435
# Train accuracy: 0.9984837174415588
#
# 14/14 [==============================] - 2s 168ms/step - loss: 0.1336 - accuracy: 0.9568
# Test loss     : 0.133610337972641
# Test accuracy : 0.956818163394928
# 14/14 [==============================] - 2s 170ms/step - loss: 0.1620 - accuracy: 0.9524
# Val loss    : 0.16202682256698608
# Val accuracy: 0.9523809552192688

# %% [markdown]
# ##Validation

# %%
import matplotlib.image as img

classes_names = ('Without helmet','With helmet')

id=np.random.randint(0, len(val)-1)

image = img.imread(val[id])

plt.imshow(image[:,:,:], cmap='gray', vmin = 0, vmax = 255,interpolation='none')
print("Ground truth: ", y_val[id].argmax(), " ", classes_names[y_val[id].argmax()])
#plt.imshow(train_x[id])

p = model_transfer_full.predict(np.expand_dims(val_x[id], axis=0))
print("Predict:      ", p.argmax(), " ", classes_names[p.argmax()])
# Out:
# Ground truth:  1   With helmet
# 1/1 [==============================] - 0s 17ms/step
# Predict:       1   With helmet
